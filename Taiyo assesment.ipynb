# %%
import numpy as np
import pandas as pd

# %%
## to read csv file

file_path = r'C:\Users\suraj\Downloads\deepak\New folder (3)\archive (4)\world_bank_projects.csv'

df = pd.read_csv(file_path, encoding='ISO-8859-1')

# %%
df.head(5)
# Out:
#         id                   regionname                         countryname
# 0  P500152      Europe and Central Asia                 Republic of Turkiye  \
# 1  P500151                   South Asia                   Republic of India
# 2  P252350  Eastern and Southern Africa                  Republic of Rwanda
# 3  P252338        East Asia and Pacific  Democratic Republic of Timor-Leste
# 4  P252337  Eastern and Southern Africa                   Republic of Kenya
#
#   projectstatusdisplay last_stage_reached_name
# 0             Pipeline                     NaN  \
# 1             Pipeline                     NaN
# 2               Active           Bank Approved
# 3               Active           Bank Approved
# 4              Dropped          Concept Review
#
#                                         project_name
# 0                        IPF Regular Project for ICR  \
# 1                                      PForR Project
# 2            Rwanda Priority Skills for Growth (PSG)
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# General Options

pd.plotting.register_matplotlib_converters()
# %matplotlib inline

sns.set_theme(palette='bright')
sns.set_context('notebook')
sns.set_style('darkgrid')

# %%
# Projects by region and status

plt.figure(figsize=(15, 8))

sns.countplot(data=df,
              y='regionname',
              order=df['regionname'].value_counts().index,
              hue='projectstatusdisplay')

plt.title("Projects by region and status", fontsize=20, fontweight='bold')
plt.ylabel("")
plt.yticks(fontweight='bold')
plt.xlabel("")
    
plt.show()

# %%
print("Number of rows ...... {:5d}".format(df.shape[0]))
print("Number of columns  .. {:5d}".format(df.shape[1]))
print("Status of projects .. {}".format(df.projectstatusdisplay.unique()))
# Out:
# Number of rows ...... 21735
# Number of columns  ..    27
# Status of projects .. ['Pipeline' 'Active' 'Dropped' nan 'Closed']

# %%
import networkx as nx

# Create an empty graph
G = nx.Graph()

# %%
# Iterate through rows in the DataFrame and add nodes and edges
for index, row in df.iterrows():
    # Extract relevant information from the row
    government = row['countryname']
    company = row['impagency']

    # Add nodes (entities) if they don't already exist
    if not G.has_node(government):
        G.add_node(government)

    if not G.has_node(company):
        G.add_node(company)

    # Add an edge (relationship) between the government and company
    G.add_edge(government, company)

# %%
# Add an edge (relationship) between the government and company
G.add_edge(government, company)
